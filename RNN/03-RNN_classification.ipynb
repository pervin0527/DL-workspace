# %%
import torch
import string
import random
import unicodedata
import numpy as np

from glob import glob
from torch import nn
from torch import optim
from torchtext import data

# %%
data_dir = "/home/pervinco/Datasets/name_classification/names"
epochs = 500
learning_rate = 0.005

# %%
all_letters = string.ascii_letters + " .,;'" ## abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ .,;'
print(f"num of letters {len(all_letters)}")
print(all_letters)
# Out:
# num of letters 57
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ .,;'

# %%
# 유니코드 문자열을 ASCII로 변환, https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn' and c in all_letters)

# %%
category_lines, all_categories = {}, []
files = glob(f"{data_dir}/*.txt")
print(len(files))

for file in files:
    category = file.split('/')[-1].split('.')[0]
    all_categories.append(category)

    with open(file, 'r') as f:
        lines = [x.strip() for x in f.readlines()]
        lines = [unicodeToAscii(line) for line in lines]
        category_lines[category] = lines

print(f"num categories : {len(all_categories)}")
# Out:
# 18
# num categories : 18

# %%
class RNN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim): ## 57, 128, 18
        super(RNN, self).__init__()

        self.hidden_dim = hidden_dim
        self.input_to_hidden = nn.Linear(input_dim + hidden_dim, hidden_dim) ## 185, 128
        self.input_to_output = nn.Linear(input_dim + hidden_dim, output_dim) ## 185, 18
        # self.softmax = nn.LogSoftmax(dim=1)
        # self.softmax = nn.Softmax(dim=1)

    def forward(self, input, hidden):
        x = torch.cat((input, hidden), dim=1)
        hidden = self.input_to_hidden(x)
        output = self.input_to_output(x)

        return output, hidden

# %%
input_dim = len(all_letters) ## 57
output_dim = len(all_categories) ## 18
hidden_dim = 128

model = RNN(input_dim, hidden_dim, output_dim)

# %%
def line_to_tensor(line):
    tensor = torch.zeros(len(line), 1, len(all_letters))
    for idx, letter in enumerate(line):
        tensor[idx][0][all_letters.find(letter)] = 1

    return tensor

test_line = category_lines['English'][7] ## Abramas
print(test_line)

test_result = line_to_tensor(test_line) ## 6, 1, 57 One-Hot Encoded vectors stack.
print(test_result.shape)
# Out:
# Abrams
# torch.Size([6, 1, 57])

# %%
def randomChoice(l):
    return l[random.randint(0, len(l) - 1)]


def randomTrainingExample():
    category = randomChoice(all_categories)
    line = randomChoice(category_lines[category])
    category_tensor = torch.tensor([all_categories.index(category)], dtype=torch.long)
    line_tensor = line_to_tensor(line)
    
    return category, line, category_tensor, line_tensor

# %%
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()
h0 = torch.zeros(1, hidden_dim)

for epoch in range(epochs):
    category, line, category_tensor, line_tensor = randomTrainingExample()
    
    optimizer.zero_grad()

    for i in range(line_tensor.size()[0]):
        output, hidden = model(line_tensor[i], h0)

    loss = criterion(output, category_tensor)
    loss.backward()
    optimizer.step()

    pred_idx = output.argmax()
    pred_label = all_categories[pred_idx]
    
    correct = 'O' if pred_label == category else 'X'
    print(f"[{epoch}/{epochs}] ({correct}) pred : {pred_label}, gt : {category}, loss : {loss.item():.4f}")
# Out:
# [0/500] (X) pred : Italian, gt : Vietnamese, loss : 2.8103
# [1/500] (X) pred : Vietnamese, gt : Greek, loss : 2.8860
# [2/500] (X) pred : Scottish, gt : Portuguese, loss : 2.9888
# [3/500] (X) pred : German, gt : Spanish, loss : 2.8725
# [4/500] (X) pred : German, gt : English, loss : 2.9320
# [5/500] (X) pred : German, gt : Scottish, loss : 2.8559
# [6/500] (X) pred : German, gt : Korean, loss : 2.8122
# [7/500] (O) pred : German, gt : German, loss : 2.7539
# [8/500] (X) pred : Vietnamese, gt : Chinese, loss : 2.8933
# [9/500] (X) pred : Vietnamese, gt : Greek, loss : 2.8999
# [10/500] (X) pred : Vietnamese, gt : Scottish, loss : 2.8167
# [11/500] (X) pred : Vietnamese, gt : French, loss : 2.9550
# [12/500] (X) pred : Vietnamese, gt : Czech, loss : 2.9237
# [13/500] (O) pred : German, gt : German, loss : 2.7152
# [14/500] (X) pred : Vietnamese, gt : Spanish, loss : 2.8932
# [15/500] (X) pred : Vietnamese, gt : Scottish, loss : 2.7755
# [16/500] (O) pred : Scottish, gt : Scottish, loss : 2.7404
# [17/500] (O) pred : Vietnamese, gt : Vietnamese, loss : 2.7180
# [18/500] (X) pred : Vietnamese, gt : Czech, loss : 2.8461
# [19/500] (X) pred : Vietnamese, gt : Czech, loss : 2.8378
# [20/500] (X) pred : Vietnamese, gt : Japanese, loss : 3.0606
# [21/500] (X) pred : German, gt : Greek, loss : 2.8358
# [22/500] (X) pred : Vietnamese, gt : Polish, loss : 2.9726
# [23/500] (X) pred : Vietnamese, gt : Scottish, loss : 2.8386
# [24/500] (X) pred : Vietnamese, gt : Czech, loss : 2.7932
# [25/500] (X) pred : Vietnamese, gt : Dutch, loss : 3.0679
# [26/500] (X) pred : German, gt : Russian, loss : 2.9926
# [27/500] (X) pred : Vietnamese, gt : Chinese, loss : 2.9159
# [28/500] (X) pred : Vietnamese, gt : Russian, loss : 3.0673
# [29/500] (O) pred : Vietnamese, gt : Vietnamese, loss : 2.7509
# [30/500] (X) pred : Vietnamese, gt : Korean, loss : 2.8577
# [31/500] (X) pred : Vietnamese, gt : Polish, loss : 2.9983
# [32/500] (O) pred : German, gt : German, loss : 2.6457
# [33/500] (X) pred : Vietnamese, gt : Italian, loss : 3.0084
# [34/500] (X) pred : Vietnamese, gt : Irish, loss : 2.9075
# [35/500] (X) pred : Vietnamese, gt : Irish, loss : 3.0554
# [36/500] (X) pred : Scottish, gt : English, loss : 2.9478
# [37/500] (X) pred : Vietnamese, gt : German, loss : 2.8354
# [38/500] (X) pred : Vietnamese, gt : Greek, loss : 2.7453
# [39/500] (X) pred : German, gt : Korean, loss : 2.7307
# [40/500] (X) pred : Korean, gt : Arabic, loss : 2.9837
# [41/500] (X) pred : Vietnamese, gt : Chinese, loss : 2.8874
# [42/500] (X) pred : Vietnamese, gt : Chinese, loss : 2.8425
# [43/500] (X) pred : German, gt : Scottish, loss : 2.7658
# [44/500] (X) pred : Scottish, gt : Chinese, loss : 2.7839
# [45/500] (X) pred : Vietnamese, gt : Arabic, loss : 3.0523
# [46/500] (X) pred : Vietnamese, gt : Irish, loss : 2.8785
# [47/500] (X) pred : Scottish, gt : Arabic, loss : 2.9547
# [48/500] (X) pred : Vietnamese, gt : Irish, loss : 2.9980
# [49/500] (X) pred : German, gt : Irish, loss : 2.9931
# [50/500] (X) pred : Vietnamese, gt : Polish, loss : 2.9428
# [51/500] (O) pred : Korean, gt : Korean, loss : 2.6833
# [52/500] (X) pred : Vietnamese, gt : Dutch, loss : 3.0197
# [53/500] (O) pred : Vietnamese, gt : Vietnamese, loss : 2.6445
# [54/500] (X) pred : Czech, gt : German, loss : 2.8295
# [55/500] (X) pred : Scottish, gt : Portuguese, loss : 2.9182
# [56/500] (X) pred : German, gt : English, loss : 2.9220
# [57/500] (X) pred : Vietnamese, gt : Korean, loss : 2.8056
# [58/500] (X) pred : Vietnamese, gt : Greek, loss : 2.7063
# [59/500] (X) pred : German, gt : Czech, loss : 2.9066
# [60/500] (O) pred : German, gt : German, loss : 2.6964
# [61/500] (X) pred : Scottish, gt : English, loss : 2.8276
# [62/500] (X) pred : Korean, gt : Vietnamese, loss : 2.8433
# [63/500] (X) pred : Scottish, gt : German, loss : 2.7068
# [64/500] (X) pred : Scottish, gt : Portuguese, loss : 2.9620
# [65/500] (X) pred : Vietnamese, gt : Italian, loss : 2.9581
# [66/500] (X) pred : German, gt : Russian, loss : 3.0505
# [67/500] (X) pred : Chinese, gt : Portuguese, loss : 2.8710
# [68/500] (X) pred : Scottish, gt : Spanish, loss : 2.8283
# [69/500] (X) pred : Czech, gt : Dutch, loss : 3.0228
# [70/500] (X) pred : Czech, gt : Portuguese, loss : 2.9711
# [71/500] (X) pred : German, gt : Czech, loss : 2.9514
# [72/500] (X) pred : Vietnamese, gt : Korean, loss : 2.7626
# [73/500] (X) pred : Vietnamese, gt : Chinese, loss : 2.7617
# [74/500] (O) pred : German, gt : German, loss : 2.5465
# [75/500] (X) pred : Vietnamese, gt : Italian, loss : 2.9206
# [76/500] (X) pred : Vietnamese, gt : Korean, loss : 2.7609
# [77/500] (X) pred : Vietnamese, gt : Irish, loss : 2.9195
# [78/500] (X) pred : Vietnamese, gt : French, loss : 3.0280
# [79/500] (X) pred : German, gt : French, loss : 2.9975
# [80/500] (O) pred : Vietnamese, gt : Vietnamese, loss : 2.6002
# [81/500] (X) pred : Vietnamese, gt : Italian, loss : 2.8867
# [82/500] (X) pred : Vietnamese, gt : Polish, loss : 2.9083
# [83/500] (X) pred : Vietnamese, gt : English, loss : 2.9877
# [84/500] (X) pred : Vietnamese, gt : Polish, loss : 2.8985
# [85/500] (X) pred : Vietnamese, gt : Russian, loss : 3.0006
# [86/500] (X) pred : Korean, gt : English, loss : 2.9111
# [87/500] (X) pred : German, gt : English, loss : 2.9180
# [88/500] (X) pred : German, gt : Spanish, loss : 2.8415
# [89/500] (O) pred : Chinese, gt : Chinese, loss : 2.6828
# [90/500] (X) pred : Vietnamese, gt : French, loss : 2.9444
# [91/500] (X) pred : German, gt : Spanish, loss : 2.8180
# [92/500] (O) pred : German, gt : German, loss : 2.5123
# [93/500] (X) pred : Vietnamese, gt : Russian, loss : 2.9695
# [94/500] (X) pred : Korean, gt : Japanese, loss : 3.1720
# [95/500] (X) pred : German, gt : Greek, loss : 2.7668
# [96/500] (X) pred : Vietnamese, gt : Arabic, loss : 3.0488
# [97/500] (X) pred : Scottish, gt : German, loss : 2.8034
# [98/500] (X) pred : Chinese, gt : Japanese, loss : 3.0714
# [99/500] (X) pred : Chinese, gt : Portuguese, loss : 2.7816
# [100/500] (X) pred : Scottish, gt : German, loss : 2.7519
# [101/500] (O) pred : German, gt : German, loss : 2.4807
# [102/500] (X) pred : German, gt : Russian, loss : 2.9112
# [103/500] (X) pred : German, gt : Scottish, loss : 2.7046
# [104/500] (X) pred : German, gt : English, loss : 2.8120
# [105/500] (X) pred : German, gt : Greek, loss : 2.7391
# [106/500] (X) pred : Chinese, gt : Italian, loss : 2.9178
# [107/500] (X) pred : Korean, gt : Japanese, loss : 3.1008
# [108/500] (X) pred : Korean, gt : Arabic, loss : 3.0421
# [109/500] (X) pred : Scottish, gt : Korean, loss : 2.7521
# [110/500] (X) pred : Vietnamese, gt : Irish, loss : 2.8854
# [111/500] (X) pred : German, gt : Greek, loss : 2.7100
# [112/500] (X) pred : German, gt : Czech, loss : 2.8294
# [113/500] (O) pred : German, gt : German, loss : 2.7126
# [114/500] (X) pred : Vietnamese, gt : Chinese, loss : 2.6967
# [115/500] (X) pred : Chinese, gt : Russian, loss : 2.9399
# [116/500] (X) pred : Scottish, gt : French, loss : 3.0448
# [117/500] (X) pred : Czech, gt : Portuguese, loss : 2.9117
# [118/500] (X) pred : German, gt : Czech, loss : 2.8478
# [119/500] (X) pred : German, gt : English, loss : 2.7660
# [120/500] (X) pred : Czech, gt : Greek, loss : 2.9185
# [121/500] (X) pred : German, gt : Czech, loss : 2.8287
# [122/500] (X) pred : German, gt : French, loss : 2.9420
# [123/500] (X) pred : Czech, gt : Portuguese, loss : 2.8771
# [124/500] (X) pred : German, gt : Arabic, loss : 3.0772
# [125/500] (X) pred : Czech, gt : Scottish, loss : 2.7912
# [126/500] (X) pred : Vietnamese, gt : Russian, loss : 2.8821
# [127/500] (X) pred : Chinese, gt : English, loss : 2.8668
# [128/500] (X) pred : German, gt : Arabic, loss : 3.1082
# [129/500] (X) pred : Korean, gt : Vietnamese, loss : 2.7760
# [130/500] (O) pred : Chinese, gt : Chinese, loss : 2.6555
# [131/500] (X) pred : German, gt : Russian, loss : 2.9013
# [132/500] (O) pred : Korean, gt : Korean, loss : 2.6982
# [133/500] (X) pred : Chinese, gt : Portuguese, loss : 2.6976
# [134/500] (X) pred : Korean, gt : Japanese, loss : 3.0251
# [135/500] (X) pred : Scottish, gt : French, loss : 2.9634
# [136/500] (O) pred : German, gt : German, loss : 2.3956
# [137/500] (X) pred : Scottish, gt : Spanish, loss : 2.7583
# [138/500] (X) pred : Czech, gt : Scottish, loss : 2.7408
# [139/500] (O) pred : German, gt : German, loss : 2.3848
# [140/500] (X) pred : Czech, gt : Japanese, loss : 2.9988
# [141/500] (O) pred : German, gt : German, loss : 2.5708
# [142/500] (X) pred : Vietnamese, gt : Scottish, loss : 2.6927
# [143/500] (X) pred : German, gt : Korean, loss : 2.7514
# [144/500] (X) pred : German, gt : Irish, loss : 2.9435
# [145/500] (X) pred : Czech, gt : French, loss : 3.0549
# [146/500] (X) pred : German, gt : English, loss : 2.6933
# [147/500] (X) pred : German, gt : Scottish, loss : 2.8033
# [148/500] (X) pred : German, gt : Spanish, loss : 2.9723
# [149/500] (X) pred : Scottish, gt : Portuguese, loss : 2.9729
# [150/500] (X) pred : Scottish, gt : French, loss : 2.8912
# [151/500] (X) pred : Vietnamese, gt : Irish, loss : 2.8583
# [152/500] (X) pred : Scottish, gt : French, loss : 2.8741
# [153/500] (X) pred : Vietnamese, gt : Scottish, loss : 2.6398
# [154/500] (X) pred : Vietnamese, gt : Dutch, loss : 3.0306
# [155/500] (X) pred : Vietnamese, gt : Korean, loss : 2.9124
# [156/500] (X) pred : Chinese, gt : Vietnamese, loss : 2.6661
# [157/500] (X) pred : Scottish, gt : Irish, loss : 3.0010
# [158/500] (X) pred : Greek, gt : Chinese, loss : 2.9007
# [159/500] (X) pred : Czech, gt : Japanese, loss : 2.9382
# [160/500] (X) pred : German, gt : Scottish, loss : 2.7197
# [161/500] (X) pred : German, gt : Portuguese, loss : 2.8174
# [162/500] (X) pred : German, gt : English, loss : 2.6905
# [163/500] (X) pred : German, gt : Irish, loss : 2.8659
# [164/500] (X) pred : Korean, gt : Italian, loss : 2.8195
# [165/500] (X) pred : Greek, gt : Vietnamese, loss : 2.6820
# [166/500] (X) pred : Scottish, gt : Dutch, loss : 2.9908
# [167/500] (X) pred : Scottish, gt : Dutch, loss : 3.2442
# [168/500] (X) pred : German, gt : Greek, loss : 2.6544
# [169/500] (X) pred : German, gt : Spanish, loss : 2.9133
# [170/500] (X) pred : German, gt : Czech, loss : 2.7497
# [171/500] (X) pred : Chinese, gt : Spanish, loss : 2.9828
# [172/500] (X) pred : Scottish, gt : Russian, loss : 2.8344
# [173/500] (X) pred : German, gt : Portuguese, loss : 2.7726
# [174/500] (X) pred : German, gt : Polish, loss : 3.0743
# [175/500] (X) pred : Irish, gt : Spanish, loss : 2.7940
# [176/500] (X) pred : Korean, gt : Polish, loss : 2.8659
# [177/500] (X) pred : Irish, gt : Czech, loss : 2.7640
# [178/500] (X) pred : German, gt : Arabic, loss : 3.0479
# [179/500] (X) pred : Scottish, gt : Dutch, loss : 2.9224
# [180/500] (X) pred : Scottish, gt : French, loss : 2.8197
# [181/500] (X) pred : Scottish, gt : Chinese, loss : 2.9728
# [182/500] (X) pred : Czech, gt : Spanish, loss : 2.7451
# [183/500] (X) pred : Czech, gt : Irish, loss : 2.7398
# [184/500] (X) pred : German, gt : Arabic, loss : 3.0118
# [185/500] (O) pred : German, gt : German, loss : 2.3362
# [186/500] (X) pred : Korean, gt : Polish, loss : 2.8102
# [187/500] (X) pred : Chinese, gt : Scottish, loss : 2.8735
# [188/500] (X) pred : German, gt : Greek, loss : 2.6235
# [189/500] (X) pred : Chinese, gt : Korean, loss : 2.6594
# [190/500] (X) pred : Scottish, gt : Irish, loss : 2.7380
# [191/500] (X) pred : Chinese, gt : Vietnamese, loss : 2.9031
# [192/500] (O) pred : Scottish, gt : Scottish, loss : 2.5646
# [193/500] (O) pred : Vietnamese, gt : Vietnamese, loss : 2.6244
# [194/500] (X) pred : German, gt : Italian, loss : 3.1167
# [195/500] (X) pred : Scottish, gt : Russian, loss : 2.8160
# [196/500] (X) pred : Spanish, gt : Portuguese, loss : 2.7383
# [197/500] (X) pred : Scottish, gt : Greek, loss : 3.0402
# [198/500] (X) pred : Scottish, gt : Irish, loss : 2.7621
# [199/500] (O) pred : Vietnamese, gt : Vietnamese, loss : 2.5867
# [200/500] (X) pred : Scottish, gt : French, loss : 2.7743
# [201/500] (X) pred : Korean, gt : German, loss : 2.6927
# [202/500] (X) pred : German, gt : French, loss : 2.7993
# [203/500] (X) pred : German, gt : Spanish, loss : 2.6973
# [204/500] (X) pred : Irish, gt : Spanish, loss : 2.6565
# [205/500] (X) pred : German, gt : Portuguese, loss : 2.7101
# [206/500] (X) pred : Korean, gt : Arabic, loss : 2.8693
# [207/500] (X) pred : Scottish, gt : English, loss : 3.0251
# [208/500] (X) pred : Scottish, gt : German, loss : 2.6266
# [209/500] (X) pred : Scottish, gt : Korean, loss : 2.8676
# [210/500] (O) pred : Scottish, gt : Scottish, loss : 2.6700
# [211/500] (X) pred : Korean, gt : Italian, loss : 2.7786
# [212/500] (X) pred : Spanish, gt : Japanese, loss : 2.8875
# [213/500] (X) pred : Vietnamese, gt : Chinese, loss : 2.8231
# [214/500] (X) pred : Scottish, gt : Greek, loss : 2.9748
# [215/500] (X) pred : German, gt : English, loss : 2.9131
# [216/500] (X) pred : German, gt : Russian, loss : 2.9379
# [217/500] (X) pred : German, gt : Arabic, loss : 3.0319
# [218/500] (X) pred : German, gt : English, loss : 2.9320
# [219/500] (X) pred : Scottish, gt : French, loss : 2.7153
# [220/500] (X) pred : Vietnamese, gt : Korean, loss : 2.6836
# [221/500] (X) pred : German, gt : Spanish, loss : 2.7873
# [222/500] (X) pred : Scottish, gt : Irish, loss : 2.7250
# [223/500] (X) pred : Scottish, gt : Irish, loss : 2.7204
# [224/500] (X) pred : German, gt : English, loss : 2.8928
# [225/500] (X) pred : Korean, gt : Vietnamese, loss : 2.8029
# [226/500] (X) pred : Vietnamese, gt : Korean, loss : 2.5935
# [227/500] (X) pred : Vietnamese, gt : Chinese, loss : 2.6040
# [228/500] (O) pred : Scottish, gt : Scottish, loss : 2.5247
# [229/500] (X) pred : German, gt : Arabic, loss : 3.0075
# [230/500] (X) pred : Scottish, gt : Spanish, loss : 2.6052
# [231/500] (X) pred : Scottish, gt : Arabic, loss : 2.8569
# [232/500] (X) pred : Scottish, gt : Arabic, loss : 2.9487
# [233/500] (X) pred : Scottish, gt : Vietnamese, loss : 2.5798
# [234/500] (X) pred : Chinese, gt : Portuguese, loss : 2.6239
# [235/500] (X) pred : German, gt : Greek, loss : 2.5737
# [236/500] (X) pred : German, gt : Greek, loss : 2.5692
# [237/500] (O) pred : Scottish, gt : Scottish, loss : 2.5006
# [238/500] (X) pred : German, gt : Russian, loss : 2.8300
# [239/500] (O) pred : German, gt : German, loss : 2.3137
# [240/500] (X) pred : Spanish, gt : French, loss : 2.7405
# [241/500] (X) pred : German, gt : Dutch, loss : 3.2337
# [242/500] (X) pred : German, gt : Czech, loss : 2.7831
# [243/500] (X) pred : German, gt : Chinese, loss : 2.9048
# [244/500] (X) pred : Scottish, gt : Arabic, loss : 2.8887
# [245/500] (X) pred : Spanish, gt : French, loss : 2.7203
# [246/500] (X) pred : Portuguese, gt : Japanese, loss : 2.9542
# [247/500] (X) pred : German, gt : Dutch, loss : 3.1897
# [248/500] (X) pred : Spanish, gt : English, loss : 2.7579
# [249/500] (X) pred : Vietnamese, gt : Japanese, loss : 3.1140
# [250/500] (O) pred : German, gt : German, loss : 2.2905
# [251/500] (X) pred : Scottish, gt : Dutch, loss : 3.0934
# [252/500] (X) pred : German, gt : English, loss : 2.7880
# [253/500] (X) pred : Czech, gt : Polish, loss : 2.9855
# [254/500] (O) pred : Korean, gt : Korean, loss : 2.6236
# [255/500] (X) pred : Scottish, gt : Korean, loss : 2.8122
# [256/500] (O) pred : Greek, gt : Greek, loss : 2.5037
# [257/500] (X) pred : Korean, gt : Spanish, loss : 2.9019
# [258/500] (O) pred : Greek, gt : Greek, loss : 2.4941
# [259/500] (X) pred : Korean, gt : Italian, loss : 2.7631
# [260/500] (O) pred : Scottish, gt : Scottish, loss : 2.5710
# [261/500] (X) pred : Spanish, gt : French, loss : 2.6617
# [262/500] (X) pred : Czech, gt : English, loss : 2.8391
# [263/500] (X) pred : Spanish, gt : French, loss : 2.6504
# [264/500] (O) pred : German, gt : German, loss : 2.2576
# [265/500] (X) pred : Scottish, gt : Russian, loss : 2.7538
# [266/500] (O) pred : Greek, gt : Greek, loss : 2.4479
# [267/500] (X) pred : German, gt : Polish, loss : 3.1028
# [268/500] (O) pred : Vietnamese, gt : Vietnamese, loss : 2.4924
# [269/500] (X) pred : Scottish, gt : Japanese, loss : 3.3318
# [270/500] (X) pred : Korean, gt : Vietnamese, loss : 2.7428
# [271/500] (X) pred : German, gt : Dutch, loss : 3.0684
# [272/500] (O) pred : German, gt : German, loss : 2.5892
# [273/500] (X) pred : Scottish, gt : Russian, loss : 2.7154
# [274/500] (X) pred : Scottish, gt : Russian, loss : 2.7947
# [275/500] (O) pred : German, gt : German, loss : 2.2239
# [276/500] (X) pred : Scottish, gt : Dutch, loss : 3.1564
# [277/500] (X) pred : German, gt : Czech, loss : 3.0249
# [278/500] (X) pred : Spanish, gt : Russian, loss : 3.0875
# [279/500] (X) pred : Scottish, gt : French, loss : 2.6401
# [280/500] (X) pred : Scottish, gt : Irish, loss : 2.6844
# [281/500] (X) pred : German, gt : Czech, loss : 3.0536
# [282/500] (X) pred : Spanish, gt : Japanese, loss : 2.8162
# [283/500] (X) pred : Korean, gt : Arabic, loss : 2.8719
# [284/500] (X) pred : Spanish, gt : Japanese, loss : 2.8030
# [285/500] (X) pred : Korean, gt : Irish, loss : 3.0476
# [286/500] (O) pred : Greek, gt : Greek, loss : 2.3907
# [287/500] (X) pred : Scottish, gt : German, loss : 2.7631
# [288/500] (X) pred : Korean, gt : Chinese, loss : 2.7800
# [289/500] (X) pred : Korean, gt : Chinese, loss : 2.5678
# [290/500] (X) pred : Scottish, gt : Chinese, loss : 2.8386
# [291/500] (X) pred : Scottish, gt : German, loss : 2.7323
# [292/500] (X) pred : Portuguese, gt : Korean, loss : 2.9487
# [293/500] (X) pred : Chinese, gt : Portuguese, loss : 2.6180
# [294/500] (X) pred : Scottish, gt : German, loss : 2.6949
# [295/500] (X) pred : German, gt : Polish, loss : 3.0745
# [296/500] (X) pred : Czech, gt : Polish, loss : 2.8843
# [297/500] (O) pred : Korean, gt : Korean, loss : 2.5669
# [298/500] (X) pred : German, gt : Dutch, loss : 3.1043
# [299/500] (X) pred : German, gt : Portuguese, loss : 2.9157
# [300/500] (X) pred : German, gt : Irish, loss : 2.6804
# [301/500] (X) pred : German, gt : English, loss : 2.6958
# [302/500] (X) pred : German, gt : Arabic, loss : 2.9142
# [303/500] (X) pred : Scottish, gt : Dutch, loss : 3.1481
# [304/500] (X) pred : Scottish, gt : Chinese, loss : 2.7681
# [305/500] (X) pred : Scottish, gt : Vietnamese, loss : 2.5722
# [306/500] (O) pred : Spanish, gt : Spanish, loss : 2.6025
# [307/500] (O) pred : Scottish, gt : Scottish, loss : 2.5086
# [308/500] (X) pred : Chinese, gt : Czech, loss : 3.0318
# [309/500] (O) pred : Greek, gt : Greek, loss : 2.3612
# [310/500] (X) pred : Greek, gt : Spanish, loss : 2.7625
# [311/500] (O) pred : German, gt : German, loss : 2.5267
# [312/500] (X) pred : German, gt : Spanish, loss : 2.6481
# [313/500] (X) pred : Chinese, gt : Korean, loss : 2.5116
# [314/500] (X) pred : German, gt : English, loss : 2.7962
# [315/500] (X) pred : Irish, gt : Czech, loss : 2.7060
# [316/500] (O) pred : German, gt : German, loss : 2.4910
# [317/500] (X) pred : German, gt : Polish, loss : 3.0271
# [318/500] (O) pred : Portuguese, gt : Portuguese, loss : 2.5631
# [319/500] (X) pred : German, gt : Spanish, loss : 2.5947
# [320/500] (X) pred : Greek, gt : Portuguese, loss : 2.6907
# [321/500] (X) pred : German, gt : English, loss : 2.6155
# [322/500] (O) pred : Greek, gt : Greek, loss : 2.3358
# [323/500] (X) pred : Greek, gt : Portuguese, loss : 2.6709
# [324/500] (X) pred : Spanish, gt : Portuguese, loss : 2.6791
# [325/500] (X) pred : German, gt : Dutch, loss : 2.9680
# [326/500] (X) pred : German, gt : Irish, loss : 2.8980
# [327/500] (X) pred : Irish, gt : English, loss : 2.9289
# [328/500] (X) pred : Portuguese, gt : Russian, loss : 2.8184
# [329/500] (X) pred : German, gt : Dutch, loss : 2.9457
# [330/500] (X) pred : Russian, gt : English, loss : 2.6714
# [331/500] (X) pred : Korean, gt : Japanese, loss : 2.9147
# [332/500] (X) pred : Irish, gt : Czech, loss : 2.6480
# [333/500] (X) pred : Spanish, gt : Arabic, loss : 3.1409
# [334/500] (X) pred : German, gt : Dutch, loss : 3.0937
# [335/500] (X) pred : Spanish, gt : Czech, loss : 2.6996
# [336/500] (X) pred : German, gt : Portuguese, loss : 2.7993
# [337/500] (X) pred : Greek, gt : German, loss : 2.4969
# [338/500] (X) pred : Spanish, gt : Japanese, loss : 2.7120
# [339/500] (X) pred : Korean, gt : German, loss : 2.7988
# [340/500] (X) pred : Scottish, gt : Korean, loss : 2.7774
# [341/500] (X) pred : Greek, gt : Portuguese, loss : 2.5641
# [342/500] (X) pred : German, gt : French, loss : 3.2060
# [343/500] (O) pred : Czech, gt : Czech, loss : 2.6207
# [344/500] (X) pred : Spanish, gt : Portuguese, loss : 2.5791
# [345/500] (O) pred : Korean, gt : Korean, loss : 2.4617
# [346/500] (X) pred : Korean, gt : Italian, loss : 2.7813
# [347/500] (X) pred : Scottish, gt : Irish, loss : 2.6518
# [348/500] (X) pred : Greek, gt : Portuguese, loss : 2.5190
# [349/500] (X) pred : Spanish, gt : Arabic, loss : 3.0625
# [350/500] (X) pred : German, gt : Dutch, loss : 2.9903
# [351/500] (O) pred : Portuguese, gt : Portuguese, loss : 2.4273
# [352/500] (X) pred : Korean, gt : Italian, loss : 2.7536
# [353/500] (O) pred : Korean, gt : Korean, loss : 2.4238
# [354/500] (O) pred : Vietnamese, gt : Vietnamese, loss : 2.4870
# [355/500] (X) pred : German, gt : Chinese, loss : 2.9419
# [356/500] (X) pred : Korean, gt : Chinese, loss : 2.5017
# [357/500] (X) pred : German, gt : Russian, loss : 2.7437
# [358/500] (X) pred : Scottish, gt : English, loss : 2.9320
# [359/500] (X) pred : Korean, gt : Vietnamese, loss : 2.7246
# [360/500] (X) pred : Scottish, gt : Vietnamese, loss : 2.5691
# [361/500] (X) pred : German, gt : Irish, loss : 2.8375
# [362/500] (X) pred : German, gt : Spanish, loss : 2.5838
# [363/500] (O) pred : Portuguese, gt : Portuguese, loss : 2.3721
# [364/500] (X) pred : German, gt : Russian, loss : 2.6935
# [365/500] (X) pred : Scottish, gt : Russian, loss : 2.7536
# [366/500] (X) pred : Korean, gt : Chinese, loss : 2.4591
# [367/500] (X) pred : Czech, gt : German, loss : 2.6364
# [368/500] (X) pred : Korean, gt : Chinese, loss : 2.4448
# [369/500] (X) pred : Portuguese, gt : Irish, loss : 2.6378
# [370/500] (X) pred : Portuguese, gt : Japanese, loss : 2.6632
# [371/500] (X) pred : Korean, gt : Italian, loss : 2.6812
# [372/500] (X) pred : Vietnamese, gt : Scottish, loss : 2.5445
# [373/500] (X) pred : Portuguese, gt : Spanish, loss : 2.5279
# [374/500] (O) pred : Czech, gt : Czech, loss : 2.5653
# [375/500] (X) pred : Czech, gt : Polish, loss : 3.1966
# [376/500] (X) pred : Vietnamese, gt : Korean, loss : 2.5814
# [377/500] (X) pred : Korean, gt : Chinese, loss : 2.3776
# [378/500] (X) pred : Korean, gt : Japanese, loss : 2.8333
# [379/500] (X) pred : Korean, gt : Vietnamese, loss : 2.5781
# [380/500] (X) pred : Vietnamese, gt : Czech, loss : 3.3148
# [381/500] (X) pred : Chinese, gt : Korean, loss : 2.3556
# [382/500] (X) pred : Vietnamese, gt : Irish, loss : 2.6083
# [383/500] (X) pred : Spanish, gt : Japanese, loss : 3.2839
# [384/500] (X) pred : Portuguese, gt : Spanish, loss : 2.8329
# [385/500] (X) pred : Korean, gt : Japanese, loss : 2.7905
# [386/500] (X) pred : Greek, gt : Spanish, loss : 2.6874
# [387/500] (X) pred : Vietnamese, gt : Korean, loss : 2.7143
# [388/500] (O) pred : Greek, gt : Greek, loss : 2.3436
# [389/500] (X) pred : Russian, gt : French, loss : 3.0764
# [390/500] (O) pred : Vietnamese, gt : Vietnamese, loss : 2.5130
# [391/500] (X) pred : German, gt : Czech, loss : 2.8331
# [392/500] (X) pred : German, gt : Dutch, loss : 2.8521
# [393/500] (X) pred : Spanish, gt : French, loss : 2.6311
# [394/500] (O) pred : German, gt : German, loss : 2.1466
# [395/500] (X) pred : German, gt : Polish, loss : 2.9289
# [396/500] (X) pred : Portuguese, gt : Vietnamese, loss : 2.8016
# [397/500] (X) pred : Greek, gt : Portuguese, loss : 2.4246
# [398/500] (X) pred : Spanish, gt : Greek, loss : 2.9080
# [399/500] (X) pred : Spanish, gt : Italian, loss : 3.4479
# [400/500] (X) pred : Vietnamese, gt : English, loss : 2.9100
# [401/500] (X) pred : Vietnamese, gt : Arabic, loss : 2.9446
# [402/500] (X) pred : Vietnamese, gt : English, loss : 2.8985
# [403/500] (X) pred : Vietnamese, gt : Korean, loss : 2.5042
# [404/500] (X) pred : Vietnamese, gt : Irish, loss : 2.5826
# [405/500] (X) pred : Vietnamese, gt : Chinese, loss : 2.7167
# [406/500] (X) pred : Spanish, gt : Chinese, loss : 3.1023
# [407/500] (O) pred : German, gt : German, loss : 2.3832
# [408/500] (X) pred : Korean, gt : Arabic, loss : 2.8135
# [409/500] (X) pred : Greek, gt : Irish, loss : 3.2700
# [410/500] (X) pred : Vietnamese, gt : Chinese, loss : 2.6892
# [411/500] (X) pred : Vietnamese, gt : Japanese, loss : 2.9221
# [412/500] (X) pred : Vietnamese, gt : Spanish, loss : 3.2972
# [413/500] (O) pred : Greek, gt : Greek, loss : 2.3048
# [414/500] (X) pred : English, gt : Irish, loss : 2.7147
# [415/500] (X) pred : Korean, gt : Vietnamese, loss : 2.6039
# [416/500] (O) pred : Spanish, gt : Spanish, loss : 2.4605
# [417/500] (X) pred : Portuguese, gt : Korean, loss : 2.8032
# [418/500] (X) pred : Greek, gt : Portuguese, loss : 2.3977
# [419/500] (X) pred : Korean, gt : Italian, loss : 2.6160
# [420/500] (X) pred : Korean, gt : Italian, loss : 2.6099
# [421/500] (X) pred : Korean, gt : Japanese, loss : 2.6836
# [422/500] (O) pred : Greek, gt : Greek, loss : 2.2796
# [423/500] (O) pred : Russian, gt : Russian, loss : 2.5910
# [424/500] (X) pred : Chinese, gt : German, loss : 2.7359
# [425/500] (X) pred : Korean, gt : Vietnamese, loss : 2.5574
# [426/500] (X) pred : German, gt : Scottish, loss : 2.8541
# [427/500] (X) pred : German, gt : Polish, loss : 2.9647
# [428/500] (X) pred : Spanish, gt : Russian, loss : 3.0028
# [429/500] (O) pred : Greek, gt : Greek, loss : 2.2506
# [430/500] (X) pred : Vietnamese, gt : Chinese, loss : 2.6166
# [431/500] (O) pred : Greek, gt : Greek, loss : 2.2376
# [432/500] (X) pred : Spanish, gt : Dutch, loss : 3.0195
# [433/500] (O) pred : Russian, gt : Russian, loss : 2.5887
# [434/500] (X) pred : Portuguese, gt : Korean, loss : 2.7429
# [435/500] (X) pred : Spanish, gt : English, loss : 2.6510
# [436/500] (X) pred : Spanish, gt : Irish, loss : 2.7464
# [437/500] (O) pred : Spanish, gt : Spanish, loss : 2.4162
# [438/500] (X) pred : Spanish, gt : Dutch, loss : 3.2374
# [439/500] (X) pred : Spanish, gt : Czech, loss : 2.6232
# [440/500] (O) pred : Portuguese, gt : Portuguese, loss : 2.3345
# [441/500] (X) pred : Czech, gt : Japanese, loss : 3.1212
# [442/500] (O) pred : Greek, gt : Greek, loss : 2.1738
# [443/500] (X) pred : Vietnamese, gt : Russian, loss : 2.7172
# [444/500] (O) pred : German, gt : German, loss : 2.4343
# [445/500] (X) pred : Portuguese, gt : Russian, loss : 2.7170
# [446/500] (X) pred : German, gt : Polish, loss : 2.8847
# [447/500] (X) pred : Spanish, gt : Italian, loss : 3.3207
# [448/500] (X) pred : Greek, gt : Scottish, loss : 2.7675
# [449/500] (X) pred : German, gt : French, loss : 3.1738
# [450/500] (O) pred : German, gt : German, loss : 2.3253
# [451/500] (O) pred : German, gt : German, loss : 2.1192
# [452/500] (X) pred : German, gt : English, loss : 2.5703
# [453/500] (X) pred : Portuguese, gt : Spanish, loss : 2.7315
# [454/500] (X) pred : Korean, gt : Polish, loss : 3.1115
# [455/500] (X) pred : Vietnamese, gt : Arabic, loss : 2.9211
# [456/500] (X) pred : Greek, gt : German, loss : 2.4666
# [457/500] (X) pred : German, gt : Arabic, loss : 2.9055
# [458/500] (X) pred : Vietnamese, gt : Scottish, loss : 2.5861
# [459/500] (X) pred : German, gt : French, loss : 2.6799
# [460/500] (X) pred : German, gt : English, loss : 2.8768
# [461/500] (O) pred : Portuguese, gt : Portuguese, loss : 2.3024
# [462/500] (X) pred : Spanish, gt : Polish, loss : 2.7873
# [463/500] (X) pred : German, gt : English, loss : 2.7187
# [464/500] (O) pred : German, gt : German, loss : 2.3224
# [465/500] (X) pred : Spanish, gt : Dutch, loss : 2.9513
# [466/500] (X) pred : Russian, gt : Polish, loss : 3.1901
# [467/500] (X) pred : Vietnamese, gt : Polish, loss : 2.6869
# [468/500] (X) pred : Vietnamese, gt : Dutch, loss : 2.8337
# [469/500] (X) pred : Spanish, gt : French, loss : 2.6108
# [470/500] (X) pred : German, gt : Dutch, loss : 3.0414
# [471/500] (X) pred : Vietnamese, gt : Polish, loss : 2.6468
# [472/500] (X) pred : Czech, gt : Irish, loss : 2.5915
# [473/500] (X) pred : German, gt : French, loss : 2.8357
# [474/500] (O) pred : Portuguese, gt : Portuguese, loss : 2.2672
# [475/500] (X) pred : Vietnamese, gt : Greek, loss : 3.1199
# [476/500] (X) pred : German, gt : Arabic, loss : 2.8801
# [477/500] (X) pred : Greek, gt : Portuguese, loss : 2.3730
# [478/500] (O) pred : Greek, gt : Greek, loss : 2.1329
# [479/500] (X) pred : Vietnamese, gt : Japanese, loss : 2.8443
# [480/500] (O) pred : German, gt : German, loss : 2.2479
# [481/500] (X) pred : Portuguese, gt : Spanish, loss : 2.6747
# [482/500] (X) pred : Spanish, gt : Japanese, loss : 2.5706
# [483/500] (O) pred : Greek, gt : Greek, loss : 2.1143
# [484/500] (O) pred : Greek, gt : Greek, loss : 2.1077
# [485/500] (X) pred : German, gt : English, loss : 2.6511
# [486/500] (X) pred : German, gt : Polish, loss : 2.6928
# [487/500] (X) pred : Vietnamese, gt : French, loss : 2.7089
# [488/500] (O) pred : German, gt : German, loss : 2.5015
# [489/500] (X) pred : Vietnamese, gt : Korean, loss : 2.7216
# [490/500] (X) pred : Greek, gt : Portuguese, loss : 2.3389
# [491/500] (X) pred : Spanish, gt : Japanese, loss : 2.5320
# [492/500] (X) pred : Portuguese, gt : Chinese, loss : 2.5892
# [493/500] (O) pred : Spanish, gt : Spanish, loss : 2.5308
# [494/500] (X) pred : Korean, gt : Vietnamese, loss : 2.5471
# [495/500] (X) pred : Spanish, gt : Vietnamese, loss : 3.2714
# [496/500] (X) pred : Vietnamese, gt : Scottish, loss : 2.5701
# [497/500] (X) pred : Korean, gt : Dutch, loss : 2.9928
# [498/500] (X) pred : Korean, gt : Vietnamese, loss : 2.7101
# [499/500] (X) pred : Russian, gt : Czech, loss : 3.0717
